# %% [markdown]
# <a href="https://colab.research.google.com/github/Chitikelagayathri/FMML-LAB-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-22 05:40:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   280MB/s    in 0.2s
#
# 2024-05-22 05:40:14 (280 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 31265  1802.08795v1  We consider the problem of binary image genera...    cs
# 7209   1711.01297v1  We interpret HyperNetworks within the framewor...  stat
# 5318    1301.3192v1  Matrix approximation is a common tool in machi...    cs
# 32026   1104.2097v1  A fundamental result of statistical learnig th...    cs
# 23647   0812.1340v2  In the paper, region based stereo matching alg...    cs
# ...             ...                                                ...   ...
# 30858  1801.06742v2  Sufficient training data is normally required ...    cs
# 16563  1704.02134v2  This document describes in detail an inventory...    cs
# 35850   1301.5943v1  The development of competitive artificial Poke...    cs
# 15477  1506.05703v1  Recently, there has been a lot of effort to re...    cs
# 23073  1803.04929v1  We present the Structural Agnostic Model (SAM)...  stat
#
#                                                    title  year  \
# 31265  Constrained Image Generation Using Binarized N...  2018
# 7209      Implicit Weight Uncertainty in Neural Networks  2017
# 5318   Matrix Approximation under Local Low-Rank Assu...  2013
# 32026  PAC learnability versus VC dimension: a footno...  2011
# 23647  Obtaining Depth Maps From Color Images By Regi...  2008
# ...                                                  ...   ...
# 30858  Multi-pseudo Regularized Label for Generated S...  2018
# 16563  Adposition and Case Supersenses v2: Guidelines...  2017
# 35850  Identifying Playerś Strategies in No Limit Tex...  2013
# 15477  "The Sum of Its Parts": Joint Learning of Word...  2015
# 23073  SAM: Structural Agnostic Model, Causal Discove...  2018
#
#                                                 keywords
# 31265  [generation, properties, practical, applicatio...
# 7209   [interpret, hypernetworks, framework, variatio...
# 5318   [approximation, prediction, recommendation, pr...
# 32026  [fundamental, statistical, learnable, dimensio...
# 23647  [algorithms, developed, extraction, informatio...
# ...                                                  ...
# 30858  [sufficient, pedestrian, identification, annot...
# 16563  [describes, inventory, characterize, adpositio...
# 35850  [development, competitive, artificial, challen...
# 15477  [represent, continuous, representations, synta...
# 23073  [structural, framework, observational, impleme...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 31265    [generation, properties, practical, applicatio...
# 7209     [interpret, hypernetworks, framework, variatio...
# 5318     [approximation, prediction, recommendation, pr...
# 32026    [fundamental, statistical, learnable, dimensio...
# 23647    [algorithms, developed, extraction, informatio...
#                                ...
# 23068    [framework, modulated, processes, frequently, ...
# 1872     [convolutional, algorithm, classification, sen...
# 2330     [adaptively, operating, conditions, effective,...
# 9529     [challenges, challenge, challenges, establishe...
# 11639    [functional, resonance, increasing, available,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8758 words.
# Out of those 4567 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="97df22a9-7713-4eec-9d8d-33c1c5005713" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97df22a9-7713-4eec-9d8d-33c1c5005713")) {                    Plotly.newPlot(                        "97df22a9-7713-4eec-9d8d-33c1c5005713",                        [{"x":["properties","binarized","constraints","procedure","generation","constrained","experiments","approximate","contribution","embedding","expensive","materials","differential","applications","generated","parameters","procedures","represents","artificial","practical","structure","computationally","topological","including","framework","variational","uncertainties","interpret","inference","hypernetworks","performance","providing","likelihood","uncertainty","distribution","predictive","distributions","classification","comparable","recommendation","improvements","approximation","assumption","prevalent","prediction","approximations","partially","representation","constructing","learnable","fundamental","surprisingly","learnability","continuum","classical","assumptions","equivalent","consistently","theoretic","dimension","consistent","additional","constructed","statistical","otherwise","hypothesis","estimation","unreliable","eliminating","increasing","information","obtaining","extraction","reliability","developed","represented","disparity","algorithms","questions","explanations","contextual","interpreting","predictions","intriguing","integrated","advantageous","different","explanation","misleading","interpretable","interprets","representations","quantifies","summarize","alignments","regularizations","affecting","architectures","supervised","iterations","initializations","equivalently","hierarchical","interpreted","variation","identifying","highlight","criticized","unexplained","convolutional","individual","evaluating","alignment","significantly","important","transparent","interpretability","literature","particular","preserving","techniques","protection","schroeder","distilled","approaches","remarkable","principles","communications","overlapping","efficiently","coefficients","transform","measurements","universal","particulars","recovered","complexity","subspaces","dimensions","knowledge","potential","compressive","compositions","orientation","exploiting","consideration","relevance","promising","summaries","microblogging","difficult","corresponding","recurrent","automatic","usefulness","introduce","summarization","challenge","diagnosis","especially","demonstrated","specificity","cognitive","dimensional","impairment","assessing","modalities","progression","structural","investigations","discriminating","delineating","comparing","investigated","effective","therefore","advantage","prodromal","biomarkers","alzheimers","cognitively","considered","challenging","discriminant","sensitive","sensitivity","relationships","representative","interactions","outperforms","displacement","effectiveness","implement","heterogeneous","straightforward","behaviors","describes","calculating","acceleration","addresses"],"y":[207,5,144,114,133,48,577,105,73,98,66,12,33,406,181,237,40,46,142,143,353,87,23,221,537,41,11,23,198,1,924,82,45,82,213,55,117,492,97,29,119,119,61,9,267,27,50,353,31,11,94,30,6,2,115,79,54,38,47,51,89,127,65,162,23,56,200,13,17,100,653,33,134,31,215,84,7,585,65,15,48,15,90,5,61,11,766,14,6,33,4,243,5,18,9,6,10,105,225,22,4,8,91,23,61,66,33,3,1,367,133,51,51,250,354,10,24,128,280,61,377,7,1,0,431,20,39,7,24,147,38,60,65,44,1,9,224,15,47,338,158,14,7,38,77,26,36,110,21,4,136,122,131,171,15,333,28,137,57,107,102,12,48,191,4,19,32,11,66,9,6,1,55,43,253,130,82,1,2,4,2,132,290,16,65,36,65,36,76,254,8,182,75,26,28,28,91,19,23,49],"type":"bar"},{"x":["properties","binarized","constraints","pro ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4567,), (4567, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Data</span> <span style='background-color:rgba(0, 255, 0, 0.4883720930232558);'>Augmentation</span> <span style=''>of</span> <span style=''>Wearable</span> <span style=''>Sensor</span> <span style=''>Data</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Parkinsons</span> <span style=''>Disease</span> <span style='background-color:rgba(0, 255, 0, 0.40740740740740744);'>Monitoring</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.6420581655480985);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>While</span> <span style='background-color:rgba(0, 255, 0, 0.6420581655480985);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(CNNs)</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successfully</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.45363408521303267);'>challenging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>they</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>require</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>for</span> <span style=''>training</span> <span style=''>When</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4482758620689655);'>availability</span> <span style=''>of</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>is</span> <span style=''>limited</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.4883720930232558);'>augmentation</span> <span style=''>is</span> <span style=''>a</span> <span style=''>critical</span> <span style='background-color:rgba(0, 255, 0, 0.5813953488372094);'>preprocessing</span> <span style=''>step</span> <span style=''>for</span> <span style=''>CNNs</span> <span style=''>However</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.4883720930232558);'>augmentation</span> <span style=''>for</span> <span style=''>wearable</span> <span style=''>sensor</span> <span style=''>data</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style=''>deeply</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigated</span> <span style=''>yet</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>various</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.4883720930232558);'>augmentation</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>wearable</span> <span style=''>sensor</span> <span style=''>data</span> <span style=''>are</span> <span style=''>proposed</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>CNNs</span> <span style=''>are</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>of</span> <span style=''>the</span> <span style=''>motor</span> <span style=''>state</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Parkinsons</span> <span style=''>Disease</span> <span style=''>patients</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.45363408521303267);'>challenging</span> <span style=''>due</span> <span style=''>to</span> <span style=''>small</span> <span style=''>dataset</span> <span style=''>size</span> <span style=''>noisy</span> <span style=''>labels</span> <span style=''>and</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Grassmannian</span> <span style=''>for</span> <span style=''>Robust</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Subspace</span> <span style=''>Recovery</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>GASG21</span> <span style=''>(Grassmannian</span> <span style=''>Adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Gradient</span> <span style=''>for</span> <span style=''>L</span> <span style=''>21</span> <span style=''>norm</span> <span style=''>minimization)</span> <span style=''>an</span> <span style=''>adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>robustly</span> <span style=''>recover</span> <span style=''>the</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>subspace</span> <span style=''>from</span> <span style=''>a</span> <span style=''>large</span> <span style=''>matrix</span> <span style=''>In</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>column</span> <span style=''>outliers</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reformulate</span> <span style=''>the</span> <span style=''>batch</span> <span style=''>mode</span> <span style=''>matrix</span> <span style=''>L</span> <span style=''>21</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>with</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Grassmann</span> <span style=''>manifold</span> <span style=''>For</span> <span style=''>each</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>vector</span> <span style=''>the</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>subspace</span> <span style=''>mathcalS</span> <span style=''>is</span> <span style=''>updated</span> <span style=''>by</span> <span style=''>taking</span> <span style=''>a</span> <span style=''>gradient</span> <span style=''>step</span> <span style=''>along</span> <span style=''>the</span> <span style=''>geodesic</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Grassmannian</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>we</span> <span style=''>choose</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adaptively</span> <span style=''>tune</span> <span style=''>the</span> <span style=''>cons ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>by</span> <span style=''>unifying</span> <span style='background-color:rgba(255, 0, 0, 0.35903614457831323);'>stochastic</span> <span style=''>gradient</span> <span style=''>and</span> <span style=''>quasi</span> <span style=''>Newton</span> <span style=''>methods</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style=''>a</span> <span style=''>sum</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>combines</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.35903614457831323);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>(SGD)</span> <span style=''>with</span> <span style=''>the</span> <span style=''>second</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>curvature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leveraged</span> <span style=''>by</span> <span style=''>quasi</span> <span style=''>Newton</span> <span style=''>methods</span> <span style=''>We</span> <span style=''>unify</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.42857142857142855);'>disparate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintaining</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>Hessian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>for</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contributing</span> <span style=''>function</span> <span style=''>in</span> <span style=''>the</span> <span style=''>sum</span> <span style=''>We</span> <span style=''>maintain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractability</span> <span style=''>and</span> <span style=''>limit</span> <span style=''>memory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirements</span> <span style=''>even</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3016453382084095);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>by</span> <span style=''>storing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.8000000000000002);'>manipulating</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.4074074074074074);'>quadratic</span> <span style='background-color:rgba(255, 0, 0, 0.5135135135135136);'>approximations</span> <span style=''>in</span> <span style=''>a</span> <span style=''>shared</span> <span style=''>time</span> <span style=''>evolving</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3016453382084095);'>dimensional</span> <span style=''>subspace</span> <span style=''>Each</span> <span style=''>update</span> <span style=''>step</span> <span style=''>requires</span> <span style=''>only</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Mahalanonbis</span> <span style=''>Distance</span> <span style=''>Informed</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style=''>question</span> <span style=''>in</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>is</span> <span style=''>how</span> <span style=''>to</span> <span style=''>compare</span> <span style=''>between</span> <span style=''>data</span> <span style=''>points</span> <span style=''>The</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>the</span> <span style=''>distance</span> <span style=''>metric</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>where</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>meaningfulness</span> <span style=''>is</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prominent</span> <span style=''>(eg</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Euclidean</span> <span style=''>distance</span> <span style=''>between</span> <span style=''>images)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>a</span> <span style=''>property</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>that</span> <span style=''>is</span> <span style=''>usually</span> <span style=''>ignored</span> <span style=''>which</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>stemming</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinates</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>organizing</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinates</span> <span style=''>in</span> <span style=''>clusters</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploited</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mahalanobis</span> <span style=''>distance</span> <span style=''>between</span> <span style=''>samples</span> <span style=''>When</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observable</span> <span style=''>samples</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transf ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	semantics (0.0475)
# 	evaluation (0.09571428571428571)
# 	architecture (0.08071428571428571)
# 	knowledge (0.12071428571428572)
# 	challenging (0.10357142857142858)
# 	segmentation (0.07285714285714286)
# 	different (0.2735714285714286)
# 	detection (0.13392857142857142)
# 	recognition (0.12857142857142856)
# 	convolutional (0.13107142857142856)
#
# Some Statistics words are:
# 	variational (0.102)
# 	statistical (0.1465)
# 	optimization (0.1925)
# 	stochastic (0.141)
# 	theoretical (0.15)
# 	distribution (0.1735)
# 	estimation (0.1805)
# 	dimensional (0.178)
# 	inference (0.201)
# 	regression (0.1775)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7e7c45af-2b9b-4a85-8346-a9466dc6e33c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e7c45af-2b9b-4a85-8346-a9466dc6e33c")) {                    Plotly.newPlot(                        "7e7c45af-2b9b-4a85-8346-a9466dc6e33c",                        [{"x":["properties","binarized","constraints","procedure","generation","constrained","experiments","approximate","contribution","embedding","expensive","materials","differential","applications","generated","parameters","procedures","represents","artificial","practical","structure","computationally","topological","including","framework","variational","uncertainties","interpret","inference","hypernetworks","performance","providing","likelihood","uncertainty","distribution","predictive","distributions","classification","comparable","recommendation","improvements","approximation","assumption","prevalent","prediction","approximations","partially","representation","constructing","learnable","fundamental","surprisingly","learnability","continuum","classical","assumptions","equivalent","consistently","theoretic","dimension","consistent","additional","constructed","statistical","otherwise","hypothesis","estimation","unreliable","eliminating","increasing","information","obtaining","extraction","reliability","developed","represented","disparity","algorithms","questions","explanations","contextual","interpreting","predictions","intriguing","integrated","advantageous","different","explanation","misleading","interpretable","interprets","representations","quantifies","summarize","alignments","regularizations","affecting","architectures","supervised","iterations","initializations","equivalently","hierarchical","interpreted","variation","identifying","highlight","criticized","unexplained","convolutional","individual","evaluating","alignment","significantly","important","transparent","interpretability","literature","particular","preserving","techniques","protection","schroeder","distilled","approaches","remarkable","principles","communications","overlapping","efficiently","coefficients","transform","measurements","universal","particulars","recovered","complexity","subspaces","dimensions","knowledge","potential","compressive","compositions","orientation","exploiting","consideration","relevance","promising","summaries","microblogging","difficult","corresponding","recurrent","automatic","usefulness","introduce","summarization","challenge","diagnosis","especially","demonstrated","specificity","cognitive","dimensional","impairment","assessing","modalities","progression","structural","investigations","discriminating","delineating","comparing","investigated","effective","therefore","advantage","prodromal","biomarkers","alzheimers","cognitively","considered","challenging","discriminant","sensitive","sensitivity","relationships","representative","interactions","outperforms","displacement","effectiveness","implement","heterogeneous","straightforward","behaviors","describes","calculating","acceleration","addresses","accommodate","quantities","consumption","calculate","processing","similarly","demonstrate","unfortunately","customization","accommodates","recognition","challenges","identification","biometric","smartphones","integrates","aforementioned","percentage","geographical","methodology","stability","normalized","frequency","replacement","distances","contained","phylogeny","associated","borrowings","collected","evolution","automated","comparative","languages","historical","measuring","understanding","complicated","orderless","evaluated","estimators","coordinate","minimized","regardless","intensity","theoretical","histograms","reference","generalized","integration","contributions","measurement","diffe ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	distilled
# 	ancestral
# 	statisticians
# 	presumably
# 	blockmodel
# 	phenotyping
# 	cumulants
# 	tolerates
# 	nonconjugate
# 	seasonality
# 	jackknife
# 	homogenous
# 	propensity
# 	impulsive
# 	unscented
# 	correntropy
# 	releasing
# 	dermatological
# 	exclusion
# 	inclusions
# Some words which never appear in Statistics papers:
# 	microblogging
# 	biometric
# 	phylogeny
# 	orderless
# 	regularisers
# 	accessing
# 	listening
# 	underwater
# 	persistency
# 	repeatability
# 	conveying
# 	dijkstras
# 	unpredictable
# 	containers
# 	hungarian
# 	deblurring
# 	minimalistic
# 	keystroke
# 	unauthorized
# 	prohibiting

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.070592931495072e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
